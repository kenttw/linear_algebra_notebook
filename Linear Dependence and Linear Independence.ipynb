# %% [markdown]
# # Linear Dependence and Linear Independence
# ## Video : <video controls src="http://140.112.161.118/dl_video.php?fn=102S207_YT06V01.mp4" />
# ## Major Tip
# * 要判斷一組向量是否為 Dependence，只要是其它的向量無法透過線性組合來產生其它的向量，就稱之這組向量為 Linear Independence
# * 換句話說就是在 $R^n$ Space 中，其這組向量的 $Rank$ 為 $n$

# %% [markdown]
# ![image.png](attachment:image.png)
