# %% [markdown]
# # Matrices and Linear Transformation
# * [上課影片](http://ocw.aca.ntu.edu.tw/ntu-ocw/index.php/ocw/cou/102S207/7/V/1?v=ntu)
# * [上課講義](http://ocw.aca.ntu.edu.tw/ocw_files/102S207/102S207_CS07L01.pdf)
# * Linear Transformatio 的示意圖
# ![image.png ](attachment:image.png)
# * $v \in R^p$ , B is $n*p$ matrix and A is $m*n$ matrix
# * so we can make a transformation $v \in R^p$ to $y \in R^m$

# %% [markdown]
# # 一些定理
# * $s(AC) = (sA)C $ s is scalar
# * $A(CP) = (AC)P $
# * $(A+B)C = AC + AB$
# * $(AC)^T = C^TA^T$
